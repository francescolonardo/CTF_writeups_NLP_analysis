# %%
# !pip install keybert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 32.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 26.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.3 MB/s eta 0:00:00
# ...
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23794 sha256=ff302be6a26325c51dbe3f5e0e8add7cf63ff4129e29ce34ade967d9d94ad3bc
#   Stored in directory: /root/.cache/pip/wheels/68/aa/41/82025d89b0eb97484c9ac7d527abf596765c41733af79f86b0
# ...

# %%
# !pip install keyphrase-vectorizers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.3 MB/s eta 0:00:00
# ...

# %%
from keybert import KeyBERT
from keyphrase_vectorizers import KeyphraseCountVectorizer

filepath = "./drive/MyDrive/sample_writeup.txt"   # specify the file path

with open(filepath, "r") as file:    # open the file in read mode
	doc = file.read()    # read the contents of the file into a string variable

kw_model = KeyBERT()
kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 1), stop_words="english", highlight=True)
#keywords = kw_model.extract_keywords(doc, vectorizer=KeyphraseCountVectorizer())
print(keywords)
# Out:
# Title Web Exploitation CTF Writeup CookieMonster Introduction In this writeup we will discuss the solution for Web
# Exploitation challenge in Capture The Flag CTF competition The challenge named CookieMonster involves exploiting
# web application cookie handling and bypassing authentication to access the flag Challenge Description The challenge
# provides link to web application which presents login form with username and password field We are also given hint
# The CookieMonster loves cookies Can you feed it the right one Tools Used Web browser Chrome Firefox Developer Tools
# built into most web browsers Burp Suite optional for intercepting and modifying HTTP requests Walkthrough Step
# Analyzing the web application Upon visiting the web application we are presented with simple login form To proceed
# we need to explore the source code and see if there are any hidden inputs or comments that might give us more
# ...
